# %%
import os
import sys
module_path = os.path.abspath(os.path.join('../../'))
if module_path not in sys.path:
    sys.path.append(module_path)

import matplotlib.pyplot as plt
from src.features.build_features import create_patches_from_imgs, retrieve_from_patches
from src.visualization.visualize import show_images
from src.data.io import get_images
import cv2

# %%
raw_data_path = '/Users/beantown/PycharmProjects/master-thesis/data/raw/exploratory_data'

matplot = True

scale = 0.25

# %%
create_patches_from_imgs(input_path=raw_data_path,
                         output_path='/Users/beantown/PycharmProjects/master-thesis/data/processed/',
                         n=4,
                         gradients=True)
# Out:
# Start collecting info from /Users/beantown/PycharmProjects/master-thesis/data/raw/exploratory_data ...
# Write info to info_file.csv
# ['Constellation-Papyri-PB1-homer-1072205286_008', 'Bodleian-Library-MS-Gr-class-a-8-P_00019_verso', 'Bodleian-Library-MS-Gr-class-a-8-P_00002_section-2-recto', 'Bodleian-Library-MS-Gr-class-a-8-P_00013_section-4-verso', 'Bodleian-Library-MS-Gr-class-a-1-P-1-10_00009_frame-9', 'Constellation-Papyri-PB1-homer-1072205286_011', 'Constellation-Papyri-PB1-homer-1072205286_013', 'Bodleian-Library-MS-Gr-class-a-1-P-1-10_00002_frame-2', 'Bodleian-Library-MS-Gr-class-a-8-P_00005_section-5-recto', 'Bodleian-Library-MS-Gr-class-a-1-P-1-10_00006_frame-6', 'Constellation-Papyri-PB1-homer-1072205286_017', 'Bodleian-Library-MS-Gr-class-a-8-P_00003_section-3-recto', 'Bodleian-Library-MS-Gr-class-a-8-P_00004_section-4-recto', 'Constellation-Papyri-PB1-homer-1072205286_015', 'Bodleian-Library-MS-Gr-class-a-8-P_00008_recto', 'Bodleian-Library-MS-Gr-class-a-1-P-1-10_00010_frame-10', 'Constellation-Papyri-PB1-homer-1072205286_012', 'Constellation-Papyri-PB1-homer-1072205286_009', 'Constellation-Papyri-PB1-homer-1072205286_010', 'Bodleian-Library-MS-Gr-class-a-1-P-1-10_00005_frame-5', 'Bodleian-Library-MS-Gr-class-a-8-P_00014_section-5-verso', 'Bodleian-Library-MS-Gr-class-a-8-P_00007_recto', 'Constellation-Papyri-PB1-homer-1072205286_014', 'Bodleian-Library-MS-Gr-class-a-8-P_00011_section-2-verso', 'Bodleian-Library-MS-Gr-class-a-1-P-1-10_00001_frame-1', 'Bodleian-Library-MS-Gr-class-a-8-P_00012_section-3-verso', 'Bodleian-Library-MS-Gr-class-a-8-P_00017_section-8-verso', 'Constellation-Papyri-PB1-homer-1072205286_016', 'Bodleian-Library-MS-Gr-class-a-8-P_00010_section-1-verso', 'Bodleian-Library-MS-Gr-class-a-8-P_00009_recto', 'Constellation-Papyri-PB1-homer-1072205286_003', 'Bodleian-Library-MS-Gr-class-a-1-P-1-10_00007_frame-7', 'Constellation-Papyri-PB1-homer-1072205286_018', 'Bodleian-Library-MS-Gr-class-a-1-P-1-10_00003_frame-3', 'Constellation-Papyri-PB1-homer-1072205286_005', 'Bodleian-Library-MS-Gr-class-a-8-P_00016_section-7-verso', 'Constellation-Papyri-PB1-homer-1072205286_007', 'Bodleian-Library-MS-Gr-class-a-1-P-1-10_00008_frame-8', 'Bodleian-Library-MS-Gr-class-a-8-P_00015_section-6-verso', 'Bodleian-Library-MS-Gr-class-a-8-P_00018_verso', 'Bodleian-Library-MS-Gr-class-a-8-P_00001_section-1-recto', 'Bodleian-Library-MS-Gr-class-a-8-P_00006_section-6-recto', 'Bodleian-Library-MS-Gr-class-a-8-P_00020_verso', 'Constellation-Papyri-PB1-homer-1072205286_002', 'Constellation-Papyri-PB1-homer-1072205286_006', 'Bodleian-Library-MS-Gr-class-a-1-P-1-10_00004_frame-4', 'Constellation-Papyri-PB1-homer-1072205286_004']
# Start collecting info from /Users/beantown/PycharmProjects/master-thesis/data/processed//8_gradient_patches/ ...
# Write info to info_file.csv
# Start collecting info from /Users/beantown/PycharmProjects/master-thesis/data/processed//8_gradient_patches/ ...
# Write info to info_file.csv
# Start collecting info from /Users/beantown/PycharmProjects/master-thesis/data/processed//8_gradient_patches/ ...
# Write info to info_file.csv
# Start collecting info from /Users/beantown/PycharmProjects/master-thesis/data/processed//8_gradient_patches/ ...
# Write info to info_file.csv
# Start collecting info from /Users/beantown/PycharmProjects/master-thesis/data/processed//8_gradient_patches/ ...
# Write info to info_file.csv
# Start collecting info from /Users/beantown/PycharmProjects/master-thesis/data/processed//8_gradient_patches/ ...
# Write info to info_file.csv
# Start collecting info from /Users/beantown/PycharmProjects/master-thesis/data/processed//8_gradient_patches/ ...
# Write info to info_file.csv
# Start collecting info from /Users/beantown/PycharmProjects/master-thesis/data/processed//8_gradient_patches/ ...
# Write info to info_file.csv
# Start collecting info from /Users/beantown/PycharmProjects/master-thesis/data/processed//8_gradient_patches/ ...
# Write info to info_file.csv
# Start collecting info from /Users/beantown/PycharmProjects/master-thesis/data/processed//8_gradient_patches/ ...
# Write info to info_file.csv
# Start collecting info from /Users/beantown/PycharmProjects/master-thesis/data/processed//8_gradient_patches/ ...
# Write info to info_file.csv
# Start collecting info from /Users/beantown/PycharmProjects/master-thesis/data/processed//8_gradient_patches/ ...
# Write info to info_file.csv
# Start collecting info from /Users/beantown/PycharmProjects/master-thesis/data/processed//8_gradient_patches/ ...
# Write info to info_file.csv
# Start collecting info from /Users/beantown/PycharmProjects/master-thesis/data/processed//8_gradient_patches/ ...
# Write info to info_file.csv
# Start collecting info from /Users/beantown/PycharmProjects/master-thesis/data/processed//8_gradient_patches/ ...
# Write info to info_file.csv
# Start collecting info from /Users/beantown/PycharmProjects/master-thesis/data/processed//8_gradient_patches/ ...
# Write info to info_file.csv
# Start collecting info from /Users/beantown/PycharmProjects/master-thesis/data/processed//8_gradient_patches/ ...
# Write info to info_file.csv
# Start collecting info from /Users/beantown/PycharmProjects/master-thesis/data/processed//8_gradient_patches/ ...
# Write info to info_file.csv
# Start collecting info from /Users/beantown/PycharmProjects/master-thesis/data/processed//8_gradient_patches/ ...
# Write info to info_file.csv
# Start collecting info from /Users/beantown/PycharmProjects/master-thesis/data/processed//8_gradient_patches/ ...
# Write info to info_file.csv
# Start collecting info from /Users/beantown/PycharmProjects/master-thesis/data/processed//8_gradient_patches/ ...
# Write info to info_file.csv
# Start collecting info from /Users/beantown/PycharmProjects/master-thesis/data/processed//8_gradient_patches/ ...
# Write info to info_file.csv
# Start collecting info from /Users/beantown/PycharmProjects/master-thesis/data/processed//8_gradient_patches/ ...
# Write info to info_file.csv
# Start collecting info from /Users/beantown/PycharmProjects/master-thesis/data/processed//8_gradient_patches/ ...
# Write info to info_file.csv
# Start collecting info from /Users/beantown/PycharmProjects/master-thesis/data/processed//8_gradient_patches/ ...
# Write info to info_file.csv
# Start collecting info from /Users/beantown/PycharmProjects/master-thesis/data/processed//8_gradient_patches/ ...
# Write info to info_file.csv
# Start collecting info from /Users/beantown/PycharmProjects/master-thesis/data/processed//8_gradient_patches/ ...
# Write info to info_file.csv
# Start collecting info from /Users/beantown/PycharmProjects/master-thesis/data/processed//8_gradient_patches/ ...
# Write info to info_file.csv
# Start collecting info from /Users/beantown/PycharmProjects/master-thesis/data/processed//8_gradient_patches/ ...
# Write info to info_file.csv
# Start collecting info from /Users/beantown/PycharmProjects/master-thesis/data/processed//8_gradient_patches/ ...
# Write info to info_file.csv
# Start collecting info from /Users/beantown/PycharmProjects/master-thesis/data/processed//8_gradient_patches/ ...
# Write info to info_file.csv
# Start collecting info from /Users/beantown/PycharmProjects/master-thesis/data/processed//8_gradient_patches/ ...
# Write info to info_file.csv
# Start collecting info from /Users/beantown/PycharmProjects/master-thesis/data/processed//8_gradient_patches/ ...
# Write info to info_file.csv
# Start collecting info from /Users/beantown/PycharmProjects/master-thesis/data/processed//8_gradient_patches/ ...
# Write info to info_file.csv
# Start collecting info from /Users/beantown/PycharmProjects/master-thesis/data/processed//8_gradient_patches/ ...
# Write info to info_file.csv
# Start collecting info from /Users/beantown/PycharmProjects/master-thesis/data/processed//8_gradient_patches/ ...
# Write info to info_file.csv
# Start collecting info from /Users/beantown/PycharmProjects/master-thesis/data/processed//8_gradient_patches/ ...
# Write info to info_file.csv
# Start collecting info from /Users/beantown/PycharmProjects/master-thesis/data/processed//8_gradient_patches/ ...
# Write info to info_file.csv
# Start collecting info from /Users/beantown/PycharmProjects/master-thesis/data/processed//8_gradient_patches/ ...
# Write info to info_file.csv
# Start collecting info from /Users/beantown/PycharmProjects/master-thesis/data/processed//8_gradient_patches/ ...
# Write info to info_file.csv
# Start collecting info from /Users/beantown/PycharmProjects/master-thesis/data/processed//8_gradient_patches/ ...
# Write info to info_file.csv
# Start collecting info from /Users/beantown/PycharmProjects/master-thesis/data/processed//8_gradient_patches/ ...
# Write info to info_file.csv
# Start collecting info from /Users/beantown/PycharmProjects/master-thesis/data/processed//8_gradient_patches/ ...
# Write info to info_file.csv
# Start collecting info from /Users/beantown/PycharmProjects/master-thesis/data/processed//8_gradient_patches/ ...
# Write info to info_file.csv
# Start collecting info from /Users/beantown/PycharmProjects/master-thesis/data/processed//8_gradient_patches/ ...
# Write info to info_file.csv
# Start collecting info from /Users/beantown/PycharmProjects/master-thesis/data/processed//8_gradient_patches/ ...
# Write info to info_file.csv
# Start collecting info from /Users/beantown/PycharmProjects/master-thesis/data/processed//8_gradient_patches/ ...
# Write info to info_file.csv
# Start collecting info from /Users/beantown/PycharmProjects/master-thesis/data/processed//8_gradient_patches/ ...
# Write info to info_file.csv

# %%
create_patches_from_imgs(input_path=raw_data_path,
                         output_path='/Users/beantown/PycharmProjects/master-thesis/data/processed/',
                         n=4,
                         gradients=False)
# Out:
# Read info from /Users/beantown/PycharmProjects/master-thesis/data/raw/exploratory_datainfo_file.csv ...
# ['Constellation-Papyri-PB1-homer-1072205286_008', 'Bodleian-Library-MS-Gr-class-a-8-P_00019_verso', 'Bodleian-Library-MS-Gr-class-a-8-P_00002_section-2-recto', 'Bodleian-Library-MS-Gr-class-a-8-P_00013_section-4-verso', 'Bodleian-Library-MS-Gr-class-a-1-P-1-10_00009_frame-9', 'Constellation-Papyri-PB1-homer-1072205286_011', 'Constellation-Papyri-PB1-homer-1072205286_013', 'Bodleian-Library-MS-Gr-class-a-1-P-1-10_00002_frame-2', 'Bodleian-Library-MS-Gr-class-a-8-P_00005_section-5-recto', 'Bodleian-Library-MS-Gr-class-a-1-P-1-10_00006_frame-6', 'Constellation-Papyri-PB1-homer-1072205286_017', 'Bodleian-Library-MS-Gr-class-a-8-P_00003_section-3-recto', 'Bodleian-Library-MS-Gr-class-a-8-P_00004_section-4-recto', 'Constellation-Papyri-PB1-homer-1072205286_015', 'Bodleian-Library-MS-Gr-class-a-8-P_00008_recto', 'Bodleian-Library-MS-Gr-class-a-1-P-1-10_00010_frame-10', 'Constellation-Papyri-PB1-homer-1072205286_012', 'Constellation-Papyri-PB1-homer-1072205286_009', 'Constellation-Papyri-PB1-homer-1072205286_010', 'Bodleian-Library-MS-Gr-class-a-1-P-1-10_00005_frame-5', 'Bodleian-Library-MS-Gr-class-a-8-P_00014_section-5-verso', 'Bodleian-Library-MS-Gr-class-a-8-P_00007_recto', 'Constellation-Papyri-PB1-homer-1072205286_014', 'Bodleian-Library-MS-Gr-class-a-8-P_00011_section-2-verso', 'Bodleian-Library-MS-Gr-class-a-1-P-1-10_00001_frame-1', 'Bodleian-Library-MS-Gr-class-a-8-P_00012_section-3-verso', 'Bodleian-Library-MS-Gr-class-a-8-P_00017_section-8-verso', 'Constellation-Papyri-PB1-homer-1072205286_016', 'Bodleian-Library-MS-Gr-class-a-8-P_00010_section-1-verso', 'Bodleian-Library-MS-Gr-class-a-8-P_00009_recto', 'Constellation-Papyri-PB1-homer-1072205286_003', 'Bodleian-Library-MS-Gr-class-a-1-P-1-10_00007_frame-7', 'Constellation-Papyri-PB1-homer-1072205286_018', 'Bodleian-Library-MS-Gr-class-a-1-P-1-10_00003_frame-3', 'Constellation-Papyri-PB1-homer-1072205286_005', 'Bodleian-Library-MS-Gr-class-a-8-P_00016_section-7-verso', 'Constellation-Papyri-PB1-homer-1072205286_007', 'Bodleian-Library-MS-Gr-class-a-1-P-1-10_00008_frame-8', 'Bodleian-Library-MS-Gr-class-a-8-P_00015_section-6-verso', 'Bodleian-Library-MS-Gr-class-a-8-P_00018_verso', 'Bodleian-Library-MS-Gr-class-a-8-P_00001_section-1-recto', 'Bodleian-Library-MS-Gr-class-a-8-P_00006_section-6-recto', 'Bodleian-Library-MS-Gr-class-a-8-P_00020_verso', 'Constellation-Papyri-PB1-homer-1072205286_002', 'Constellation-Papyri-PB1-homer-1072205286_006', 'Bodleian-Library-MS-Gr-class-a-1-P-1-10_00004_frame-4', 'Constellation-Papyri-PB1-homer-1072205286_004']
# Start collecting info from /Users/beantown/PycharmProjects/master-thesis/data/processed//8_patches/ ...
# Write info to info_file.csv
# Start collecting info from /Users/beantown/PycharmProjects/master-thesis/data/processed//8_patches/ ...
# Write info to info_file.csv
# Start collecting info from /Users/beantown/PycharmProjects/master-thesis/data/processed//8_patches/ ...
# Write info to info_file.csv
# Start collecting info from /Users/beantown/PycharmProjects/master-thesis/data/processed//8_patches/ ...
# Write info to info_file.csv
# Start collecting info from /Users/beantown/PycharmProjects/master-thesis/data/processed//8_patches/ ...
# Write info to info_file.csv
# Start collecting info from /Users/beantown/PycharmProjects/master-thesis/data/processed//8_patches/ ...
# Write info to info_file.csv
# Start collecting info from /Users/beantown/PycharmProjects/master-thesis/data/processed//8_patches/ ...
# Write info to info_file.csv
# Start collecting info from /Users/beantown/PycharmProjects/master-thesis/data/processed//8_patches/ ...
# Write info to info_file.csv
# Start collecting info from /Users/beantown/PycharmProjects/master-thesis/data/processed//8_patches/ ...
# Write info to info_file.csv
# Start collecting info from /Users/beantown/PycharmProjects/master-thesis/data/processed//8_patches/ ...
# Write info to info_file.csv
# Start collecting info from /Users/beantown/PycharmProjects/master-thesis/data/processed//8_patches/ ...
# Write info to info_file.csv
# Start collecting info from /Users/beantown/PycharmProjects/master-thesis/data/processed//8_patches/ ...
# Write info to info_file.csv
# Start collecting info from /Users/beantown/PycharmProjects/master-thesis/data/processed//8_patches/ ...
# Write info to info_file.csv
# Start collecting info from /Users/beantown/PycharmProjects/master-thesis/data/processed//8_patches/ ...
# Write info to info_file.csv
# Start collecting info from /Users/beantown/PycharmProjects/master-thesis/data/processed//8_patches/ ...
# Write info to info_file.csv
# Start collecting info from /Users/beantown/PycharmProjects/master-thesis/data/processed//8_patches/ ...
# Write info to info_file.csv
# Start collecting info from /Users/beantown/PycharmProjects/master-thesis/data/processed//8_patches/ ...
# Write info to info_file.csv
# Start collecting info from /Users/beantown/PycharmProjects/master-thesis/data/processed//8_patches/ ...
# Write info to info_file.csv
# Start collecting info from /Users/beantown/PycharmProjects/master-thesis/data/processed//8_patches/ ...
# Write info to info_file.csv
# Start collecting info from /Users/beantown/PycharmProjects/master-thesis/data/processed//8_patches/ ...
# Write info to info_file.csv
# Start collecting info from /Users/beantown/PycharmProjects/master-thesis/data/processed//8_patches/ ...
# Write info to info_file.csv
# Start collecting info from /Users/beantown/PycharmProjects/master-thesis/data/processed//8_patches/ ...
# Write info to info_file.csv
# Start collecting info from /Users/beantown/PycharmProjects/master-thesis/data/processed//8_patches/ ...
# Write info to info_file.csv
# Start collecting info from /Users/beantown/PycharmProjects/master-thesis/data/processed//8_patches/ ...
# Write info to info_file.csv
# Start collecting info from /Users/beantown/PycharmProjects/master-thesis/data/processed//8_patches/ ...
# Write info to info_file.csv
# Start collecting info from /Users/beantown/PycharmProjects/master-thesis/data/processed//8_patches/ ...
# Write info to info_file.csv
# Start collecting info from /Users/beantown/PycharmProjects/master-thesis/data/processed//8_patches/ ...
# Write info to info_file.csv
# Start collecting info from /Users/beantown/PycharmProjects/master-thesis/data/processed//8_patches/ ...
# Write info to info_file.csv
# Start collecting info from /Users/beantown/PycharmProjects/master-thesis/data/processed//8_patches/ ...
# Write info to info_file.csv
# Start collecting info from /Users/beantown/PycharmProjects/master-thesis/data/processed//8_patches/ ...
# Write info to info_file.csv
# Start collecting info from /Users/beantown/PycharmProjects/master-thesis/data/processed//8_patches/ ...
# Write info to info_file.csv
# Start collecting info from /Users/beantown/PycharmProjects/master-thesis/data/processed//8_patches/ ...
# Write info to info_file.csv
# Start collecting info from /Users/beantown/PycharmProjects/master-thesis/data/processed//8_patches/ ...
# Write info to info_file.csv
# Start collecting info from /Users/beantown/PycharmProjects/master-thesis/data/processed//8_patches/ ...
# Write info to info_file.csv
# Start collecting info from /Users/beantown/PycharmProjects/master-thesis/data/processed//8_patches/ ...
# Write info to info_file.csv
# Start collecting info from /Users/beantown/PycharmProjects/master-thesis/data/processed//8_patches/ ...
# Write info to info_file.csv
# Start collecting info from /Users/beantown/PycharmProjects/master-thesis/data/processed//8_patches/ ...
# Write info to info_file.csv
# Start collecting info from /Users/beantown/PycharmProjects/master-thesis/data/processed//8_patches/ ...
# Write info to info_file.csv
# Start collecting info from /Users/beantown/PycharmProjects/master-thesis/data/processed//8_patches/ ...
# Write info to info_file.csv
# Start collecting info from /Users/beantown/PycharmProjects/master-thesis/data/processed//8_patches/ ...
# Write info to info_file.csv
# Start collecting info from /Users/beantown/PycharmProjects/master-thesis/data/processed//8_patches/ ...
# Write info to info_file.csv
# Start collecting info from /Users/beantown/PycharmProjects/master-thesis/data/processed//8_patches/ ...
# Write info to info_file.csv
# Start collecting info from /Users/beantown/PycharmProjects/master-thesis/data/processed//8_patches/ ...
# Write info to info_file.csv
# Start collecting info from /Users/beantown/PycharmProjects/master-thesis/data/processed//8_patches/ ...
# Write info to info_file.csv
# Start collecting info from /Users/beantown/PycharmProjects/master-thesis/data/processed//8_patches/ ...
# Write info to info_file.csv
# Start collecting info from /Users/beantown/PycharmProjects/master-thesis/data/processed//8_patches/ ...
# Write info to info_file.csv
# Start collecting info from /Users/beantown/PycharmProjects/master-thesis/data/processed//8_patches/ ...
# Write info to info_file.csv
# Start collecting info from /Users/beantown/PycharmProjects/master-thesis/data/processed//8_patches/ ...
# Write info to info_file.csv

# %%
files = ['Bodleian-Library-MS-Gr-class-a-1-P-1-10_00001_frame-1_edges_x',
         'Bodleian-Library-MS-Gr-class-a-1-P-1-10_00001_frame-1_edges_y']
info = show_images(raw_data_path='/Users/beantown/PycharmProjects/master-thesis/data/processed/8_gradient_patches/',
                   all=False,
                   file_names=files,
                   rand=False,
                   scaler=scale,
                   print_info=True,
                   print_overview=False,
                   matplot=matplot,
                   label=1)
# Out:
# Read info from /Users/beantown/PycharmProjects/master-thesis/data/processed/8_gradient_patches/info_file.csv ...
#
# Read info from /Users/beantown/PycharmProjects/master-thesis/data/processed/8_gradient_patches/info_file.csv ...
#
# File Info
#
# |   Unnamed: 0 | names                                                         |   widths |   heights |   labels |
# |--------------|---------------------------------------------------------------|----------|-----------|----------|
# |           92 | Bodleian-Library-MS-Gr-class-a-1-P-1-10_00001_frame-1_edges_x |     2672 |      1588 |        1 |
# |          175 | Bodleian-Library-MS-Gr-class-a-1-P-1-10_00001_frame-1_edges_y |     2672 |      1588 |        1 |

# %%
files = ['Bodleian-Library-MS-Gr-class-a-1-P-1-10_00001_frame-1_edges_x',
         'Bodleian-Library-MS-Gr-class-a-1-P-1-10_00001_frame-1_edges_y']
gradient_images = get_images(raw_data_path='/Users/beantown/PycharmProjects/master-thesis/data/processed/8_gradient_patches/',
                    file_names=files,
                    rand=False,
                    scaler=None,
                    print_info=False,
                    print_overview=False,
                    label=1)
# Out:
# Read info from /Users/beantown/PycharmProjects/master-thesis/data/processed/8_gradient_patches/info_file.csv ...

# %%
print(len(gradient_images))
# Out:
# 2

# %%
files = ['Bodleian-Library-MS-Gr-class-a-1-P-1-10_00001_frame-1']
patched_images = get_images(raw_data_path='/Users/beantown/PycharmProjects/master-thesis/data/processed/8_patches/',
                            file_names=files,
                            rand=False,
                            scaler=None,
                            print_info=False,
                            print_overview=False,
                            label=1)
print(len(patched_images))
# Out:
# Read info from /Users/beantown/PycharmProjects/master-thesis/data/processed/8_patches/info_file.csv ...
# 1

# %%
test_img_vertical = patched_images - gradient_images[0]
test_img_horizontal = patched_images - gradient_images[1]
test_img = (patched_images - gradient_images[0]) - gradient_images[1]

if matplot:
    img = cv2.cvtColor(patched_images[0], cv2.COLOR_BGR2RGB)
    test_img_vertical = cv2.cvtColor(test_img_vertical[0], cv2.COLOR_BGR2RGB)
    test_img_horizontal = cv2.cvtColor(test_img_horizontal[0], cv2.COLOR_BGR2RGB)
    test_img = cv2.cvtColor(test_img[0], cv2.COLOR_BGR2RGB)
    plt.figure()
    plt.title('Img original.')
    plt.imshow(img)
    plt.figure()
    plt.title('Img without vertical edges.')
    plt.imshow(test_img_vertical)
    plt.show()
    plt.figure()
    plt.title('Img without horizontal edges.')
    plt.imshow(test_img_horizontal)
    plt.show()
    plt.figure()
    plt.title('Img without both edges.')
    plt.imshow(test_img)
    plt.show()
else:
    cv2.imshow('Original - patched', patched_images)
    cv2.imshow('Img without vertical edges.', test_img_vertical[0])
    cv2.imshow('Img without horizontal edges.', test_img_horizontal[0])
    cv2.waitKey(0)
    cv2.destroyAllWindows()
